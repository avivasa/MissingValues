# %% [markdown]
# ## Categoria Missing
#
# Este notebook tem como objetivo apresentar o uso do classe sklearn.impute para imputação da categoria missing .  Vou utilizar como exemplo o Dataset do Titanic.

# %% [markdown]
# ### Importação das Bibliotecas

# %%
# trabalhar com dataframes
import pandas as pd
# trabalhar com arrays
import numpy as np
# gráficos
import matplotlib.pyplot as plt
# técnica de imputação
from sklearn.impute import SimpleImputer
# Divisão em Conjunto de Teste e Treinamento
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import MissingIndicator

# %% [markdown]
# ### Importação do Dataset

# %%
data = pd.read_csv('/home/vivas/Pesquisa/Datasets/Titanic/train.csv')
print(data.shape)
data.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# verficar valores faltantes 
data.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %% [markdown]
# ###  Verificar Tipos

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Dividir o dataset
# Aplicamos sempre a imputação no conjunto de treinamento

# %%
features=data.columns
print(features)
# remover a feature Survived pois ela é o target
features.drop('Survived')
print(features)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(data[features], # just the features
                                                    data['Survived'], # the target
                                                    test_size=0.3, # the percentage of obs in the test set
                                                    random_state=0) # for reproducibility
X_train.shape, X_test.shape
# Out:
# ((623, 12), (268, 12))

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Usando o Missing Indicator

# %%
indicator = MissingIndicator(error_on_new=True, features='missing-only')
indicator.fit(X_train)
# Out:
# MissingIndicator(error_on_new=True, features='missing-only', missing_values=nan,
#                  sparse='auto')

# %% [markdown]
# ### Índices das features onde serão aplicadas os indicadores

# %%
indicator.features_
# Out:
# array([ 5, 10, 11])

# %% [markdown]
# ### Nome das features

# %%
X_train.columns[indicator.features_]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# ### Matriz dos indicadores

# %%
indices=indicator.transform(X_train)

# %% [markdown]
# ### Inserir indicadores no conjunto de teste e treinamento

# %%
indicator_cols = [i+'_VA' for i in X_train.columns[indicator.features_]]

# and now we concatenate
X_train = pd.concat([
    X_train.reset_index(),
    pd.DataFrame(indices, columns = indicator_cols)],
    axis=1)

X_train.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0    857          858         1       1
# 1     52           53         1       1
# 2    386          387         0       3
# 3    124          125         0       1
# 4    578          579         0       3
#
#                                        Name     Sex   Age  SibSp  Parch  \
# 0                    Daly, Mr. Peter Denis     male  51.0      0      0
# 1  Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1      0
# 2           Goodwin, Master. Sidney Leonard    male   1.0      5      2
# 3               White, Mr. Percival Wayland    male  54.0      0      1
# 4          Caram, Mrs. Joseph (Maria Elias)  female   NaN      1      0
#
#      Ticket     Fare Cabin Embarked  Age_VA  Cabin_VA  Embarked_VA
# 0    113055  26.5500   E17        S   False     False        False
# 1  PC 17572  76.7292   D33        C   False     False        False
# 2   CA 2144  46.9000   NaN        S   False      True        False
# 3     35281  77.2875   D26        S   False     False        False
# 4      2689  14.4583   NaN        C    True      True        False

# %%
tmp = indicator.transform(X_test)
indicator_cols = [i+'_VA' for i in X_test.columns[indicator.features_]]

X_test = pd.concat([
    X_test.reset_index(),
    pd.DataFrame(tmp, columns = indicator_cols)],
    axis=1)

X_test.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0    495          496         0       3
# 1    648          649         0       3
# 2    278          279         0       3
# 3     31           32         1       1
# 4    255          256         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                           Yousseff, Mr. Gerious    male   NaN      0      0
# 1                              Willey, Mr. Edward    male   NaN      0      0
# 2                              Rice, Master. Eric    male   7.0      4      1
# 3  Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1      0
# 4         Touma, Mrs. Darwis (Hanne Youssef Razi)  female  29.0      0      2
#
#           Ticket      Fare Cabin Embarked  Age_VA  Cabin_VA  Embarked_VA
# 0           2627   14.4583   NaN        C    True      True        False
# 1  S.O./P.P. 751    7.5500   NaN        S    True      True        False
# 2         382652   29.1250   NaN        Q   False      True        False
# 3       PC 17569  146.5208   B78        C    True     False        False
# 4           2650   15.2458   NaN        C   False      True        False

# %%
# Vamos definir as estratégias 
numericas = ['PassengerId','Pclass','Age','SibSp','Parch','Fare']
categoricas = ['Name','Sex','Cabin','Embarked','Ticket','Age_VA','Cabin_VA','Embarked_VA']

Imputer_numericas = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
])

Imputer_categoricas = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant',fill_value = 'Missing')),
])

# aplicação do ColumnTransformer

Processamento = ColumnTransformer(transformers=[
    ('Imputer_numericas', Imputer_numericas, numericas),
    ('Imputer_categoricas', Imputer_categoricas, categoricas)
])

# now we fit the preprocessor
Processamento.fit(X_train)
# Out:
# ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('Imputer_numericas',
#                                  Pipeline(memory=None,
#                                           steps=[('imputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                                 fill_value=None,
#                                                                 missing_values=nan,
#                                                                 strategy='mean',
#                                                                 verbose=0))],
#                                           verbose=False),
#                                  ['PassengerId', 'Pclass', 'Age', 'SibSp',
#                                   'Parch', 'Fare']),
#                                 ('Imputer_categoricas',
#                                  Pipeline(memory=None,
#                                           steps=[('imputer',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                                 fill_value='Missing',
#                                                                 missing_values=nan,
#                                                                 strategy='constant',
#                                                                 verbose=0))],
#                                           verbose=False),
#                                  ['Name', 'Sex', 'Cabin', 'Embarked', 'Ticket',
#                                   'Age_VA', 'Cabin_VA', 'Embarked_VA'])],
#                   verbose=False)

# %%
# Podemos olhar o valor imputado imputada
Processamento.transformers
# Out:
# [('Imputer_numericas', Pipeline(memory=None,
#            steps=[('imputer',
#                    SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                  missing_values=nan, strategy='mean',
#                                  verbose=0))],
#            verbose=False), ['PassengerId',
#    'Pclass',
#    'Age',
#    'SibSp',
#    'Parch',
#    'Fare']),
#  ('Imputer_categoricas', Pipeline(memory=None,
#            steps=[('imputer',
#                    SimpleImputer(add_indicator=False, copy=True,
#                                  fill_value='Missing', missing_values=nan,
#                                  strategy='constant', verbose=0))],
#            verbose=False), ['Name',
#    'Sex',
#    'Cabin',
#    'Embarked',
#    'Ticket',
#    'Age_VA',
#    'Cabin_VA',
#    'Embarked_VA'])]

# %%
X_train
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0      857          858         1       1
# 1       52           53         1       1
# 2      386          387         0       3
# 3      124          125         0       1
# 4      578          579         0       3
# ..     ...          ...       ...     ...
# 618    835          836         1       1
# 619    192          193         1       3
# 620    629          630         0       3
# 621    559          560         1       3
# 622    684          685         0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                             Daly, Mr. Peter Denis     male  51.0      0
# 1           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 2                    Goodwin, Master. Sidney Leonard    male   1.0      5
# 3                        White, Mr. Percival Wayland    male  54.0      0
# 4                   Caram, Mrs. Joseph (Maria Elias)  female   NaN      1
# ..                                               ...     ...   ...    ...
# 618                      Compton, Miss. Sara Rebecca  female  39.0      1
# 619  Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0      1
# 620                         O'Connell, Mr. Patrick D    male   NaN      0
# 621     de Messemaeker, Mrs. Guillaume Joseph (Emma)  female  36.0      1
# 622                Brown, Mr. Thomas William Solomon    male  60.0      1
#
#      Parch    Ticket     Fare Cabin Embarked  Age_VA  Cabin_VA  Embarked_VA
# 0        0    113055  26.5500   E17        S   False     False        False
# 1        0  PC 17572  76.7292   D33        C   False     False        False
# 2        2   CA 2144  46.9000   NaN        S   False      True        False
# 3        1     35281  77.2875   D26        S   False     False        False
# 4        0      2689  14.4583   NaN        C    True      True        False
# ..     ...       ...      ...   ...      ...     ...       ...          ...
# 618      1  PC 17756  83.1583   E49        C   False     False        False
# 619      0    350046   7.8542   NaN        S   False      True        False
# 620      0    334912   7.7333   NaN        Q    True      True        False
# 621      0    345572  17.4000   NaN        S   False      True        False
# 622      1     29750  39.0000   NaN        S   False      True        False
#
# [623 rows x 16 columns]

# %%
X_test
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0      495          496         0       3
# 1      648          649         0       3
# 2      278          279         0       3
# 3       31           32         1       1
# 4      255          256         1       3
# ..     ...          ...       ...     ...
# 263    263          264         0       1
# 264    718          719         0       3
# 265    620          621         0       3
# 266    786          787         1       3
# 267     64           65         0       1
#
#                                                Name     Sex   Age  SibSp  \
# 0                             Yousseff, Mr. Gerious    male   NaN      0
# 1                                Willey, Mr. Edward    male   NaN      0
# 2                                Rice, Master. Eric    male   7.0      4
# 3    Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 4           Touma, Mrs. Darwis (Hanne Youssef Razi)  female  29.0      0
# ..                                              ...     ...   ...    ...
# 263                           Harrison, Mr. William    male  40.0      0
# 264                             McEvoy, Mr. Michael    male   NaN      0
# 265                             Yasbeck, Mr. Antoni    male  27.0      1
# 266                       Sjoblom, Miss. Anna Sofia  female  18.0      0
# 267                           Stewart, Mr. Albert A    male   NaN      0
#
#      Parch         Ticket      Fare Cabin Embarked  Age_VA  Cabin_VA  \
# 0        0           2627   14.4583   NaN        C    True      True
# 1        0  S.O./P.P. 751    7.5500   NaN        S    True      True
# 2        1         382652   29.1250   NaN        Q   False      True
# 3        0       PC 17569  146.5208   B78        C    True     False
# 4        2           2650   15.2458   NaN        C   False      True
# ..     ...            ...       ...   ...      ...     ...       ...
# 263      0         112059    0.0000   B94        S   False     False
# 264      0          36568   15.5000   NaN        Q    True      True
# 265      0           2659   14.4542   NaN        C   False      True
# 266      0        3101265    7.4958   NaN        S   False      True
# 267      0       PC 17605   27.7208   NaN        C    True      True
#
#      Embarked_VA
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 263        False
# 264        False
# 265        False
# 266        False
# 267        False
#
# [268 rows x 16 columns]

# %% [markdown]
# ### verificação dos valores

# %%
Processamento.named_transformers_['Imputer_numericas'].named_steps['imputer'].statistics_
# Out:
# array([4.47678973e+02, 2.28731942e+00, 2.99153386e+01, 5.31300161e-01,
#        3.93258427e-01, 3.24582726e+01])

# %%
X_train["Age"].mean()
# Out:
# 29.915338645418327

# %%
Processamento.named_transformers_['Imputer_categoricas'].named_steps['imputer'].statistics_
# Out:
# array(['Missing', 'Missing', 'Missing', 'Missing', 'Missing', 'Missing',
#        'Missing', 'Missing'], dtype=object)

# %%
# Agora vamos imputar nos conjuntos de treinamento e teste

X_train = Processamento.transform(X_train)
X_test = Processamento.transform(X_test)

# %%
X_train
# Out:
# array([[858.0, 1.0, 51.0, ..., False, False, False],
#        [53.0, 1.0, 49.0, ..., False, False, False],
#        [387.0, 3.0, 1.0, ..., False, True, False],
#        ...,
#        [630.0, 3.0, 29.915338645418327, ..., True, True, False],
#        [560.0, 3.0, 36.0, ..., False, True, False],
#        [685.0, 2.0, 60.0, ..., False, True, False]], dtype=object)

# %%
X_test
# Out:
# array([[496.0, 3.0, 29.915338645418327, ..., True, True, False],
#        [649.0, 3.0, 29.915338645418327, ..., True, True, False],
#        [279.0, 3.0, 7.0, ..., False, True, False],
#        ...,
#        [621.0, 3.0, 27.0, ..., False, True, False],
#        [787.0, 3.0, 18.0, ..., False, True, False],
#        [65.0, 1.0, 29.915338645418327, ..., True, True, False]],
#       dtype=object)
